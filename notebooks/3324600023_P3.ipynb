# %%
#latihan 1
def menu():
    print("\nMenu:")
    print("1. Tulis ke File")
    print("2. Baca dari File")
    print("3. Keluar")
    return input("Pilih opsi (1/2/3): ")

def tulis_ke_file():
    with open("e:/SEMESTER 2/PEMROGRAMAN 2 (BU LELY)/coba 6 maret.txt", 'w') as file:  
        teks = input("Masukkan teks: ")
        file.write(teks)
        print("Teks berhasil ditulis.")

def baca_dari_file():
    try:
        with open("data.txt", 'r') as file:  
            print("Isi file:")
            print(file.read())
    except FileNotFoundError:
        print("File tidak ditemukan.")

while True:
    pilihan = menu()
    if pilihan == '1':
        tulis_ke_file()
    elif pilihan == '2':
        baca_dari_file()
    elif pilihan == '3':
        print("Program selesai.")
        break
    else:
        print("Pilihan tidak valid.")
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\S'
# <>:10: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_8880\2561225705.py:10: SyntaxWarning: invalid escape sequence '\S'
#   with open("e:\SEMESTER 2\PEMROGRAMAN 2 (BU LELY)\coba 6 maret.txt", 'w') as file:
# Menu:
# 1. Tulis ke File
# 2. Baca dari File
# 3. Keluar
# Pilihan tidak valid.
#
# Menu:
# 1. Tulis ke File
# 2. Baca dari File
# 3. Keluar
# Pilihan tidak valid.
#
# Menu:
# 1. Tulis ke File
# 2. Baca dari File
# 3. Keluar
# Pilihan tidak valid.
#
# Menu:
# 1. Tulis ke File
# 2. Baca dari File
# 3. Keluar

# %%
#latihan 2 
def menu():
    print ("\nMenu:")
    print("1. Tulis ke File")
    print("2. Baca dari File")
    print("3. Keluar")
    return input("Pilih opsi (1/2/3): ")

def tulis_ke_file():
    nama_file = "data.txt"
    with open(nama_file, 'w') as file: 
        teks = input("Masukkan teks: ")
        file.write(teks)  
        print("Teks berhasil ditulis ke file.")

def baca_dari_file():
    nama_file = "data.txt"
    try:
        with open(nama_file, 'r') as file:  
            print("Isi file:")
            print(file.read())  
    except FileNotFoundError:
        print("File tidak ditemukan. Harap buat file terlebih dahulu.")

while True:
    pilihan = menu()
    if pilihan == '1':
        tulis_ke_file()
    elif pilihan == '2':
        baca_dari_file()
    elif pilihan == '3':
        print("Program selesai.")
        break
    else:
        print("Pilihan tidak valid.")
