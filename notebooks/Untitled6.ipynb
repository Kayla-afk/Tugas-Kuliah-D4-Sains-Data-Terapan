# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Baca file TSV
df = pd.read_csv('title_basics.tsv', sep='\t', encoding='utf-8')

# Simpan sebagai CSV
df.to_csv('title_basics.csv', index=False, encoding='utf-8')

# Cek beberapa data awal
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-211cb416a722> in <cell line: 0>()
#       4
#       5 # Baca file TSV
# ----> 6 df = pd.read_csv('title_basics.tsv', sep='\t', encoding='utf-8')
#       7
#       8 # Simpan sebagai CSV
#
# ...
