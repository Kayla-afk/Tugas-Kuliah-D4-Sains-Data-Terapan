# %%
import cv2
#Mengambil data video camera, misal di simpan divariabel cam
cam=cv2.VideoCapture(0) #jika cameranya hanya ada diurutan
pertama, di isi 1 jika urutan ke dua dst
cam.set(3,640) #Ubah lebar cam
cam.set(4,480) #ubah tinggi cam
faceDetector=cv2.CascadeClassifier('haarcascade_frontalface_defaul
t.xml')
#karena mengambil video secara berulang-ulang, kondisinya bisa
True atau False jika kamera tidak bisa ON
while True: # dibutuhkan perulangan dengan kondisi True:
 #pengambilan data dikamera yang diambil adalah Retriaval Value
dan Gambar setiap framenya
 retV, frame=cam.read() #membaca data dari variabel cam yg
digunakan untuk mengambil data camera
 gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) # warna gambar
setiap frame abu-abu
 faces=faceDetector.detectMultiScale(gray,1.3,5) #frame, scale
factor [1-2] makin mendekati 2 makin cepat tp kurang bagus
 # dan Min
Neigborhood=bobotnya deafultnya 5 nilai sekitar pixel tetangga
 for(x,y,w,h) in faces:
 frame=cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
#membuat kotak dalam deteksi wajahnya

 cv2.imshow("Web Camera Warna",frame) #menampikan data gambar
setiap per-frame-nya dengan warna aslinya
 #cv2.imshow("Web Camera Gray",gray) #menampikan data gambar
setiap per-frame-nya dengan warna abu-abu
 k=cv2.waitKey(1) & 0xFF
 if k==27 or k==ord('q'): #karena gambar tiap frame
diambil terus menerus maka hrs tombol berhenti jika esc atau q
 break
cam.release() #supaya space data memory di computer tidak penuh
maka data camera di release
cv2.destroyAllWindows() #termasuk dilakukan destroy semua
windownya spy tdk penuh
# Out:
#   File "<ipython-input-1-562fbc446a6b>", line 7
#     faceDetector=cv2.CascadeClassifier('haarcascade_frontalface_defaul
#                                        ^
# SyntaxError: unterminated string literal (detected at line 7)
