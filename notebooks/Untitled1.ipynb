# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install kaggle

# %%
! pip install -q kaggle

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download competitions/fathomnet-out-of-sample-detection/data/
# Out:
# 403 - Forbidden - Permission 'competitions.participate' was denied

# %%
df = pd.read_csv('/content/category_key.csv')
print(df.to_string())
# Out:
#       id                                     name       supercat
# 0      1                               Actiniaria        Anemone
# 1      2                               Actinernus        Anemone
# 2      3                               Actiniidae        Anemone
# 3      4                            Actinoscyphia        Anemone
# 4      5                                 Bolocera        Anemone
# 5      6                                Dofleinia        Anemone
# 6      7                             Hormathiidae        Anemone
# 7      8                              Isosicyonis        Anemone
# 8      9                      Liponema brevicorne        Anemone
# 9     10                       Metridium farcimen        Anemone
# 10    11                           Actinopterygii           Fish
# 11    12                                 Agonidae           Fish
# 12    13                   Albatrossia pectoralis           Fish
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/category_key.csv')
print(df.to_string())
# Out:
#       id                                     name       supercat
# 0      1                               Actiniaria        Anemone
# 1      2                               Actinernus        Anemone
# 2      3                               Actiniidae        Anemone
# 3      4                            Actinoscyphia        Anemone
# 4      5                                 Bolocera        Anemone
# 5      6                                Dofleinia        Anemone
# 6      7                             Hormathiidae        Anemone
# 7      8                              Isosicyonis        Anemone
# 8      9                      Liponema brevicorne        Anemone
# 9     10                       Metridium farcimen        Anemone
# 10    11                           Actinopterygii           Fish
# 11    12                                 Agonidae           Fish
# 12    13                   Albatrossia pectoralis           Fish
# ...

# %%
import pandas as pd
df = pd.read_json('/content/category_key.csv')
print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-eaa5cebcdf54> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_json('/content/category_key.csv')
#       3 print(df.to_string())
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813         return json_reader
#     814     else:
# --> 815         return json_reader.read()
#     816
#     817
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in read(self)
#    1023                         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024                 else:
# ...
