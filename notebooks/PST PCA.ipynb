# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv(r"E:/SEMESTER 2/PRAKTIKUM PST SMT 2/Wine.csv")
x = dataset.iloc[:, 0:13].values
y = dataset.iloc[:, 13].values
print(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-4d90a8014fcf> in <cell line: 0>()
# ----> 1 dataset = pd.read_csv(r"E:/SEMESTER 2/PRAKTIKUM PST SMT 2/Wine.csv")
#       2 x = dataset.iloc[:, 0:13].values
#       3 y = dataset.iloc[:, 13].values
#       4 print(x)
#       5 print(y)
#
# ...

# %%
import pandas as pd

# Load the dataset (ensure the file path is correct and accessible)
dataset = pd.read_csv(r"E:/SEMESTER 2/PRAKTIKUM PST SMT 2/Wine.csv")

# Splitting the dataset into features (X) and labels (Y)
x = dataset.iloc[:, :-1].values  # Selecting all columns except the last one
y = dataset.iloc[:, -1].values   # Selecting only the last column

# Print the features and labels
print(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-b76c1f577304> in <cell line: 0>()
#       2
#       3 # Load the dataset (ensure the file path is correct and accessible)
# ----> 4 dataset = pd.read_csv(r"E:/SEMESTER 2/PRAKTIKUM PST SMT 2/Wine.csv")
#       5
#       6 # Splitting the dataset into features (X) and labels (Y)
#
# ...
